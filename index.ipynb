# %% [markdown]
# # Join Statements - Lab
#
# ## Introduction
#
# In this lab, you'll practice your knowledge of `JOIN` statements, using various types of joins and various methods for specifying the links between them.
#
# ## Objectives
#
# You will be able to:
#
# * Write SQL queries that make use of various types of joins
# * Compare and contrast the various types of joins
# * Discuss how primary and foreign keys are used in SQL
# * Decide and perform whichever type of join is best for retrieving desired data

# %% [markdown]
# ## CRM ERD
#
# In this lab, you'll use the same customer relationship management (CRM) database that you saw from the previous lesson.
# <img src='https://curriculum-content.s3.amazonaws.com/data-science/images/Database-Schema.png' width="600">

# %% [markdown]
# ## Connecting to the Database
# Import the necessary packages and connect to the database `'data.sqlite'`.

# %%
import pandas as pd
import sqlite3
conn = sqlite3.connect('data.sqlite')

# %% [markdown]
# ## Select the names of all employees in Boston
#
# Hint: join the employees and offices tables. Select the first and last name.

# %%
pd.read_sql("""
SELECT firstName, lastName
    FROM employees AS e
        JOIN offices AS o
            ON e.officeCode = o.officeCode
""", conn
)
# Out:
#    firstName   lastName
# 0      Diane     Murphy
# 1       Mary  Patterson
# 2       Jeff   Firrelli
# 3    William  Patterson
# 4     Gerard     Bondur
# 5    Anthony        Bow
# 6     Leslie   Jennings
# 7     Leslie   Thompson
# 8      Julie   Firrelli
# 9      Steve  Patterson
# 10  Foon Yue      Tseng
# 11    George     Vanauf
# 12      Loui     Bondur
# 13    Gerard  Hernandez
# 14    Pamela   Castillo
# 15     Larry       Bott
# 16     Barry      Jones
# 17      Andy     Fixter
# 18     Peter      Marsh
# 19       Tom       King
# 20      Mami      Nishi
# 21   Yoshimi       Kato
# 22    Martin     Gerard

# %% [markdown]
# ## Are there any offices that have zero employees?
# Hint: Combine the employees and offices tables and use a group by. Select the office code, city, and number of employees.

# %%
pd.read_sql("""
SELECT *
FROM offices AS o
LEFT JOIN employees AS e
ON o.officeCode = e.officeCode

""", conn
)
# Out:
#     officeCode           city             phone              addressLine1  \
# 0            1  San Francisco   +1 650 219 4782         100 Market Street
# 1            1  San Francisco   +1 650 219 4782         100 Market Street
# 2            1  San Francisco   +1 650 219 4782         100 Market Street
# 3            1  San Francisco   +1 650 219 4782         100 Market Street
# 4            1  San Francisco   +1 650 219 4782         100 Market Street
# 5            1  San Francisco   +1 650 219 4782         100 Market Street
# 6            2         Boston   +1 215 837 0825          1550 Court Place
# 7            2         Boston   +1 215 837 0825          1550 Court Place
# 8            3            NYC   +1 212 555 3000      523 East 53rd Street
# 9            3            NYC   +1 212 555 3000      523 East 53rd Street
# 10           4          Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans
# 11           4          Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans
# 12           4          Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans
# 13           4          Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans
# 14           4          Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans
# 15           5          Tokyo   +81 33 224 5000               4-1 Kioicho
# 16           5          Tokyo   +81 33 224 5000               4-1 Kioicho
# 17           6         Sydney   +61 2 9264 2451     5-11 Wentworth Avenue
# 18           6         Sydney   +61 2 9264 2451     5-11 Wentworth Avenue
# 19           6         Sydney   +61 2 9264 2451     5-11 Wentworth Avenue
# 20           6         Sydney   +61 2 9264 2451     5-11 Wentworth Avenue
# 21           7         London  +44 20 7877 2041       25 Old Broad Street
# 22           7         London  +44 20 7877 2041       25 Old Broad Street
# 23          27         Boston   +1 977 299 8345      105 Cambridge Street
#
#    addressLine2       state    country postalCode territory  employeeNumber  \
# 0     Suite 300          CA        USA      94080        NA          1002.0
# 1     Suite 300          CA        USA      94080        NA          1056.0
# 2     Suite 300          CA        USA      94080        NA          1076.0
# 3     Suite 300          CA        USA      94080        NA          1143.0
# 4     Suite 300          CA        USA      94080        NA          1165.0
# 5     Suite 300          CA        USA      94080        NA          1166.0
# 6     Suite 102          MA        USA      02107        NA          1188.0
# 7     Suite 102          MA        USA      02107        NA          1216.0
# 8       apt. 5A          NY        USA      10022        NA          1286.0
# 9       apt. 5A          NY        USA      10022        NA          1323.0
# 10                              France      75017      EMEA          1102.0
# 11                              France      75017      EMEA          1337.0
# 12                              France      75017      EMEA          1370.0
# 13                              France      75017      EMEA          1401.0
# 14                              France      75017      EMEA          1702.0
# 15               Chiyoda-Ku      Japan   102-8578     Japan          1621.0
# 16               Chiyoda-Ku      Japan   102-8578     Japan          1625.0
# 17     Floor #2              Australia   NSW 2010      APAC          1088.0
# 18     Floor #2              Australia   NSW 2010      APAC          1611.0
# 19     Floor #2              Australia   NSW 2010      APAC          1612.0
# 20     Floor #2              Australia   NSW 2010      APAC          1619.0
# 21      Level 7                     UK   EC2N 1HN      EMEA          1501.0
# 22      Level 7                     UK   EC2N 1HN      EMEA          1504.0
# 23                       MA        USA      02331        NA             NaN
#
#      lastName firstName extension                            email  \
# 0      Murphy     Diane     x5800     dmurphy@classicmodelcars.com
# 1   Patterson      Mary     x4611   mpatterso@classicmodelcars.com
# 2    Firrelli      Jeff     x9273   jfirrelli@classicmodelcars.com
# 3         Bow   Anthony     x5428        abow@classicmodelcars.com
# 4    Jennings    Leslie     x3291   ljennings@classicmodelcars.com
# 5    Thompson    Leslie     x4065   lthompson@classicmodelcars.com
# 6    Firrelli     Julie     x2173   jfirrelli@classicmodelcars.com
# 7   Patterson     Steve     x4334  spatterson@classicmodelcars.com
# 8       Tseng  Foon Yue     x2248      ftseng@classicmodelcars.com
# 9      Vanauf    George     x4102     gvanauf@classicmodelcars.com
# 10     Bondur    Gerard     x5408     gbondur@classicmodelcars.com
# 11     Bondur      Loui     x6493     lbondur@classicmodelcars.com
# 12  Hernandez    Gerard     x2028   ghernande@classicmodelcars.com
# 13   Castillo    Pamela     x2759   pcastillo@classicmodelcars.com
# 14     Gerard    Martin     x2312     mgerard@classicmodelcars.com
# 15      Nishi      Mami      x101      mnishi@classicmodelcars.com
# 16       Kato   Yoshimi      x102       ykato@classicmodelcars.com
# 17  Patterson   William     x4871  wpatterson@classicmodelcars.com
# 18     Fixter      Andy      x101     afixter@classicmodelcars.com
# 19      Marsh     Peter      x102      pmarsh@classicmodelcars.com
# 20       King       Tom      x103       tking@classicmodelcars.com
# 21       Bott     Larry     x2311       lbott@classicmodelcars.com
# 22      Jones     Barry      x102      bjones@classicmodelcars.com
# 23       None      None      None                             None
#
#     officeCode reportsTo              jobTitle
# 0          1.0                       President
# 1          1.0      1002              VP Sales
# 2          1.0      1002          VP Marketing
# 3          1.0      1056    Sales Manager (NA)
# 4          1.0      1143             Sales Rep
# 5          1.0      1143             Sales Rep
# 6          2.0      1143             Sales Rep
# 7          2.0      1143             Sales Rep
# 8          3.0      1143             Sales Rep
# 9          3.0      1143             Sales Rep
# 10         4.0      1056   Sale Manager (EMEA)
# 11         4.0      1102             Sales Rep
# 12         4.0      1102             Sales Rep
# 13         4.0      1102             Sales Rep
# 14         4.0      1102             Sales Rep
# 15         5.0      1056             Sales Rep
# 16         5.0      1621             Sales Rep
# 17         6.0      1056  Sales Manager (APAC)
# 18         6.0      1088             Sales Rep
# 19         6.0      1088             Sales Rep
# 20         6.0      1088             Sales Rep
# 21         7.0      1102             Sales Rep
# 22         7.0      1102             Sales Rep
# 23         NaN      None                  None

# %%
pd.read_sql("""
SELECT o.officeCode, o.city, COUNT(e.employeeNumber) AS num_employees
FROM offices AS o
LEFT JOIN employees AS e
ON o.officeCode = e.officeCode
GROUP BY o.officeCode, o.city
HAVING num_employees = 0
""", conn
)
# Out:
#    officeCode    city  num_employees
# 0          27  Boston              0

# %% [markdown]
# ## Write 3 questions of your own and answer them

# %%
# Answers will vary

# Example question: 
"""
How many customers are there per office?
"""

# %%
pd.read_sql(\
"""
SELECT * FROM offices
""", conn
)

# %%
"""
Question 1
"""

pd.read_sql(\
"""
SELECT o.city, COUNT(*) AS num_of_customers
FROM customers AS c
JOIN employees AS e ON c.salesRepEmployeeNumber = e.employeeNumber
JOIN offices AS o ON e.officeCode = o.officeCode
GROUP BY o.officeCode
""", conn
)
# Out:
#             city  num_of_customers
# 0  San Francisco                12
# 1         Boston                12
# 2            NYC                15
# 3          Paris                29
# 4          Tokyo                 5
# 5         Sydney                10
# 6         London                17

# %%
"""
Question 2
"""

# Your code here

# %%
"""
Question 3
"""

# Your code here

# %% [markdown]
# ## Level Up 1: Display the names of every individual product that each employee has sold
#
# Hint: You will need to use multiple `JOIN` clauses to connect all the way from employee names to product names.

# %%
pd.read_sql(\
"""
SELECT e.firstName, e.lastName, p.productName
FROM employees AS e
JOIN customers AS c ON e.employeeNumber = c.salesRepEmployeeNumber 
JOIN orders AS od ON c.customerNumber = od.customerNumber
JOIN orderdetails AS odd ON od.orderNumber = odd.orderNumber
JOIN products AS p ON odd.productCode = p.productCode
 
""", conn
)
# Out:
#      firstName  lastName                                  productName
# 0       Leslie  Jennings                               1958 Setra Bus
# 1       Leslie  Jennings                       1940 Ford Pickup Truck
# 2       Leslie  Jennings                      1939 Cadillac Limousine
# 3       Leslie  Jennings  1996 Peterbilt 379 Stake Bed with Outrigger
# 4       Leslie  Jennings                            1968 Ford Mustang
# ...        ...       ...                                          ...
# 2991    Martin    Gerard                  1954 Greyhound Scenicruiser
# 2992    Martin    Gerard       1950's Chicago Surface Lines Streetcar
# 2993    Martin    Gerard             Diamond T620 Semi-Skirted Tanker
# 2994    Martin    Gerard                           1911 Ford Town Car
# 2995    Martin    Gerard             1936 Mercedes Benz 500k Roadster
#
# [2996 rows x 3 columns]

# %% [markdown]
# ## Level Up 2: Display the number of products each employee has sold
#
# Alphabetize the results by employee last name.
#
# Hint: Use the `quantityOrdered` column from `orderDetails`. Also, think about how to group the data when some employees might have the same first or last name.

# %%
# Your code here

# %% [markdown]
# ## Level Up 3: Display the names employees who have sold more than 200 different products
#
# Hint: this is different from the previous question because the quantity sold doesn't matter, only the number of different products

# %%
# Your code here

# %% [markdown]
# ## Summary

# %% [markdown]
# Congrats! You practiced using join statements and leveraged your foreign keys knowledge!
